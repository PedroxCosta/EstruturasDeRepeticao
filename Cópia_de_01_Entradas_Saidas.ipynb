# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroxCosta/EstruturasDeRepeticao/blob/main/C%C3%B3pia_de_01_Entradas_Saidas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [JD0007] Introdução à Linguagem de Programação (C$#$)
#
#  Murilo Boratto$^1$
#
# $^1$ Colegiado de Jogos Digitais <br />
#      &nbsp;&nbsp;&nbsp; Departamento de Ciências Exatas e da Terra I <br />
#      &nbsp;&nbsp;&nbsp; Universidade do Estado da Bahia (UNEB), Salvador, Bahia, Brasil

# %% [markdown]
# # Instalação  C$#$

# %% [markdown]
# Este é o passo a passo de como instalar o C# em ambiente virtual do Colab, utilizando a implementação open source do C#, o mono, sem utilizar qualquer IDE.

# %%
# !sudo apt-get install mono-devel
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   binfmt-support ca-certificates-mono cli-common libgdiplus libmono-2.0-dev
#   libmono-accessibility4.0-cil libmono-btls-interface4.0-cil
#   libmono-cairo4.0-cil libmono-cecil-private-cil libmono-cil-dev
#   libmono-codecontracts4.0-cil libmono-compilerservices-symbolwriter4.0-cil
#   libmono-corlib4.5-cil libmono-cscompmgd0.0-cil libmono-csharp4.0c-cil
#   libmono-custommarshalers4.0-cil libmono-data-tds4.0-cil libmono-db2-1.0-cil
#   libmono-debugger-soft4.0a-cil libmono-http4.0-cil libmono-i18n-cjk4.0-cil
#   libmono-i18n-mideast4.0-cil libmono-i18n-other4.0-cil
#   libmono-i18n-rare4.0-cil libmono-i18n-west4.0-cil libmono-i18n4.0-all
#   libmono-i18n4.0-cil libmono-ldap4.0-cil libmono-management4.0-cil
#   libmono-messaging-rabbitmq4.0-cil libmono-messaging4.0-cil
#   libmono-microsoft-build-engine4.0-cil
# ...

# %%
# !mono --version
# Out:
# Mono JIT compiler version 6.8.0.105 (Debian 6.8.0.105+dfsg-2 Wed Feb 26 23:23:50 UTC 2020)
# Copyright (C) 2002-2014 Novell, Inc, Xamarin Inc and Contributors. www.mono-project.com
# 	TLS:           __thread
# 	SIGSEGV:       altstack
# 	Notifications: epoll
# 	Architecture:  amd64
# 	Disabled:      none
# 	Misc:          softdebug
# 	Interpreter:   yes
# 	LLVM:          supported, not enabled.
# 	Suspend:       hybrid
# 	GC:            sgen (concurrent by default)

# %% [markdown]
# ## Hello World!

# %%
# %%writefile hello.cs
# using System;
#
# public class Program
# {
#     public static void Main()
#     {
#
#     int numerodetermos, primeirovalordapa, razao, contador;
#
#      Console.WriteLine("Por Favor Digite o Primeiro Elemento da PA:");
#      primeirovalordapa = int.Parse(Console.ReadLine());
#
#      Console.WriteLine("Por Favor Digite a Razao:");
#      razao = int.Parse(Console.ReadLine());
#
#      Console.WriteLine("Por Favor Digite o numero de termos:");
#      numerodetermos = int.Parse(Console.ReadLine());
#
#      for(contador = 0; contador < numerodetermos; contador++){
#      Console.WriteLine(contador);
#      }
#
#     }
# }
# Out:
# Overwriting hello.cs

# %%
# !mcs hello.cs -out:hello
# Out:
# hello.cs(8,25): warning CS0219: The variable `primeirovalordapa' is assigned but its value is never used
# hello.cs(8,44): warning CS0219: The variable `razao' is assigned but its value is never used
# Compilation succeeded - 2 warning(s)

# %%
# !mono hello
# Out:
# Por Favor Digite o Primeiro Elemento da PA:
# =1
# Por Favor Digite a Razao:
# 2
# Por Favor Digite o numero de termos:
# 5
# 0
# 1
# 2
# 3
# 4
# >

# %%
# %%writefile variavel.cs
# using System;
#
# namespace myApp
# {
#    class Program
#    {
#        static void Main()
#        {
#
#        int contador;
#
#        for(contador = 0; contador <= 10; contador = contador + 1)
#        {
#          Console.WriteLine(contador);
#        }
#
#
#
#
#
#
#
#        }
#    }
# }
# Out:
# Overwriting variavel.cs

# %%
# !mcs variavel.cs -out:variavel

# %%
# !mono variavel

# %% [markdown]
# # Entradas e Saídas

# %% [markdown]
# ## Armazenamento nas Variáveis

# %%
# %%writefile variaveis.cs
# using System;
#
# namespace myApp
# {
#  class Program
#  {
#    static void Main()
#    {
#       float A = 5f;
#       float B = 2.5f;
#       float C = 2f;
#
#       Console.WriteLine("A + B * C = {0}", A + B * C);
#       Console.WriteLine("(A + B) * C = {0}", (A + B) * C);
#       Console.WriteLine("A + C * B = {0}", A + C * B);
#       Console.WriteLine("A + B * C /2 = {0}", A + B * C/2);
#       Console.WriteLine("(A + B * C) /2 = {0}", (A + B * C)/2);
#
#    }
#  }
# }

# %%
# !mcs variaveis.cs -out:variaveis

# %%
# !mono variaveis

# %% [markdown]
# ## Altura

# %%
# %%writefile altura.cs
# using System;
#
# namespace myApp
# {
#  class Program
#  {
#    static void Main()
#    {
#       float altura;
#
#       Console.WriteLine("Informe sua altura: ");
#       altura = float.Parse(Console.ReadLine());
#
#       Console.WriteLine("Altura digitada foi: {0}", altura);
#
#    }
#  }
# }

# %%
# !mcs altura.cs -out:altura

# %%
# !mono altura

# %% [markdown]
# ## Gasolina

# %% [markdown]
# Escreva um programa capaz de calcular o **preço médio da gasolina** considerando três postos de
# combustível de Salvador. Solicitando ao usuário que informe o valor da gasolina em cada
# um dos três postos.

# %%
# %%writefile gasolina.cs
# using System;
#
# namespace myApp
# {
#   class Gasolina
#   {
#     static void Main()
#     {
#         float valorPosto1, valorPosto2, valorPosto3, mediaReaisPrecosGasolinas;
#
#         Console.WriteLine ("Entre com o valor da Gasolina do Posto 1:");
#         valorPosto1 = float.Parse(Console.ReadLine());
#
#         Console.WriteLine ("Entre com o valor da Gasolina do Posto 2:");
#         valorPosto2 = float.Parse(Console.ReadLine());
#
#         Console.WriteLine ("Entre com o valor da Gasolina do Posto 3:");
#         valorPosto3 = float.Parse(Console.ReadLine());
#
#         mediaReaisPrecosGasolinas = (valorPosto1 + valorPosto2 + valorPosto3)/3;
#
#         Console.WriteLine ("Valor Médio da Gasolina é (R$): {0}",  mediaReaisPrecosGasolinas);
#     }
#   }
# }

# %%
# !mcs gasolina.cs -out:gasolina

# %%
# !mono gasolina

# %% [markdown]
# ## Idade

# %% [markdown]
# Escreva um programa que pergunte o **nome** e a **idade** de um individuo e imprima (aproximadamente) **quantos dias de vida ele possui**.

# %%
# %%writefile idade.cs
# using System;
#
# namespace myApp
# {
#   class Idade
#   {
#     static void Main()
#     {
#         string nome;
#         int idade, numeroDiasTerra;
#
#         Console.Write("Digite o nome: ");
#         nome = Console.ReadLine();
#
#         Console.Write("Digite a idade: ");
#         idade = int.Parse(Console.ReadLine());
#
#         numeroDiasTerra = idade * 365;
#
#         Console.WriteLine("{0}  você tem  {1} dias de vida na terra", nome, numeroDiasTerra);
#     }
#   }
# }

# %%
# !mcs idade.cs -out:idade

# %%
# !mono idade
